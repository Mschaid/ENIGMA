# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shap
import xgboost as xgb
import yaml

from functools import partial
from pathlib import Path
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import cross_val_score

# local imports
from hydra import compose, initialize
from src.data_processing.model_analyzers.xgb_analyzers.XGBRegAnalyzer import XGBRegAnalyzerFactory
from src.data_processing.model_analyzers.xgb_analyzers.XGBRegrResults import XGBRegrResults

# %%
local_data_path = "/Users/mds8301/iterm_data_storage/raw_data_raw_data.parquet.gzip"

# %%
da_only_path = '/Users/mds8301/Development/ENIGMA/results/experiments/xgb_regression_da_only_hyperopt_tune'
da_with_day_path = '/Users/mds8301/Development/ENIGMA/results/experiments/xgb_regression_da_with_day_hyperopt_tune'

da_only_analyzer = XGBRegAnalyzerFactory(da_only_path).create_analyzer()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 4
#       1 da_only_path = '/Users/mds8301/Development/ENIGMA/results/experiments/xgb_regression_da_only_hyperopt_tune'
#       2 da_with_day_path = '/Users/mds8301/Development/ENIGMA/results/experiments/xgb_regression_da_with_day_hyperopt_tune'
# ----> 4 da_only_analyzer = XGBRegAnalyzerFactory(da_only_path).create_analyzer()
#
# File ~/Development/ENIGMA/src/data_processing/model_analyzers/xgb_analyzers/XGBRegAnalyzer.py:239, in XGBRegAnalyzerFactory.create_analyzer(self, cls_to_drop)
#     237 def create_analyzer(self, cls_to_drop: List[str] = None) -> XGBRegAnalyzer:
#     238     analyzer = XGBRegAnalyzer(self.results)
# --> 239     analyzer.create_pipeline(cls_to_drop)
#     240     analyzer.fit_best_xgb_model()
#     241     return analyzer
#
# ...

# %%
da_only_analyzer.plot_shapley_results()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 da_only_analyzer.plot_shapley_results()
#
# AttributeError: 'XGBRegAnalyzerFactory' object has no attribute 'plot_shapley_results'

# %%
visualizer.plot_shap_results()
# Out:
# is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
